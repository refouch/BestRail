# %%
import requests
import pandas as pd
import datetime
from datetime import datetime, timedelta, time
import networkx as nx

# %%
API_KEY = ""

# %% [markdown]
# # Gares

# %% [markdown]
# Dans cette partie on récupère toutes les gares SNCF pour les grandes lignes et les lignes régionales

# %%
def get_stop_points(base_url, api_key):
    """
    Fonction pour récupérer tous les stop_points 
    """
    all_stop_points = []
    page = 0

    #requêtes page par page
    while True:
        params = {
            "count": 1000, 
            "start_page": page}

        r = requests.get(base_url, params=params, auth=(api_key, ""))
        data = r.json()

        stop_points = data.get("stop_points", [])

        if not stop_points:
            break 

        all_stop_points.extend(stop_points)
        page += 1

    return pd.json_normalize(all_stop_points)

# %%
# récupérer les stop_points des longues distances et train régionaux
df_stations_1 = get_stop_points('https://api.navitia.io/v1/coverage/sncf/physical_modes/physical_mode:LongDistanceTrain/stop_points?', API_KEY)
df_stations_2 = get_stop_points('https://api.navitia.io/v1/coverage/sncf/physical_modes/physical_mode:Train/stop_points?', API_KEY)

# %%
def process_station_data(df):
    """
    Fonction pour traiter les données des stations :
    - Extraction des informations administratives
    - Filtrage des données (stations non françaises, non ferroviaires)
    """
    
    # Extraction des informations administratives
    df["admin"] = df["administrative_regions"].apply(
        lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None
    )
    df["admin_id"] = df["admin"].apply(lambda x: x.get("id") if isinstance(x, dict) else None)
    df["admin_zip"] = df["admin"].apply(lambda x: x.get("zip_code") if isinstance(x, dict) else None)
    df["admin_label"] = df["admin"].apply(lambda x: x.get("label") if isinstance(x, dict) else None)
    df["code_insee"] = df["admin"].apply(lambda x: x.get("insee") if isinstance(x, dict) else None)

    # Suppression des colonnes inutiles
    df = df.drop(columns=["administrative_regions", "admin", "links", "equipments"])

    # Retirer la première ligne si elle est vide
    df = df.drop(0, errors='ignore')

    # Retirer les stations non françaises
    df = df.loc[lambda x: x['admin_id'].str.contains('fr', na=False)]

    # Retirer les lignes non ferroviaires (bus)
    df = df[df['id'].str.contains("Train", na=False)]

    return df

# %%
df_stations_2 = process_station_data(df_stations_2)
df_stations_1 = process_station_data(df_stations_1)

# %%
#il y a des stations TGV qui ne sont pas des LongDistanceTrain, on les retire
df_stations_1 = df_stations_1.loc[df_stations_1['id'].str.contains("LongDistanceTrain", na=False)]

# %%
df_stations_2.loc[lambda x: x['id'].str.contains('LongDistanceTrain', na=False)]
# Out:
#                                               id              name  \
# 3     stop_point:SNCF:87342048:LongDistanceTrain            Achiet
# 560   stop_point:SNCF:87781161:LongDistanceTrain           Coursan
# 1362  stop_point:SNCF:87781294:LongDistanceTrain  Marseillan Plage
# 1435  stop_point:SNCF:87747329:LongDistanceTrain           Moirans
# 2309  stop_point:SNCF:87781260:LongDistanceTrain              Vias
#
#                               label coord.lon  coord.lat  \
# 3          Achiet (Achiet-le-Grand)  2.780112  50.131919
# 560               Coursan (Coursan)  3.050946  43.233731
# 1362  Marseillan Plage (Marseillan)  3.535629  43.318258
# 1435              Moirans (Moirans)  5.581934   45.32216
# 2309                    Vias (Vias)  3.425356  43.315653
#
#                  stop_area.id    stop_area.name  \
# 3     stop_area:SNCF:87342048            Achiet
# 560   stop_area:SNCF:87781161           Coursan
# 1362  stop_area:SNCF:87781294  Marseillan Plage
# 1435  stop_area:SNCF:87747329           Moirans
# 2309  stop_area:SNCF:87781260              Vias
#
#                                         stop_area.codes stop_area.timezone  \
# 3     [{'type': 'source', 'value': '87342048'}, {'ty...       Europe/Paris
# 560   [{'type': 'source', 'value': '87781161'}, {'ty...       Europe/Paris
# 1362  [{'type': 'source', 'value': '87781294'}, {'ty...       Europe/Paris
# 1435  [{'type': 'source', 'value': '87747329'}, {'ty...       Europe/Paris
# 2309  [{'type': 'source', 'value': '87781260'}, {'ty...       Europe/Paris
#
#                     stop_area.label stop_area.coord.lon stop_area.coord.lat  \
# 3          Achiet (Achiet-le-Grand)            2.780112           50.131919
# 560               Coursan (Coursan)            3.050946           43.233731
# 1362  Marseillan Plage (Marseillan)            3.535629           43.318258
# 1435              Moirans (Moirans)            5.581934            45.32216
# 2309                    Vias (Vias)            3.425356           43.315653
#
#      stop_area.links        admin_id admin_zip              admin_label  \
# 3                 []  admin:fr:62005     62121  Achiet-le-Grand (62121)
# 560               []  admin:fr:11106     11110          Coursan (11110)
# 1362              []  admin:fr:34150     34340       Marseillan (34340)
# 1435              []  admin:fr:38239     38430          Moirans (38430)
# 2309              []  admin:fr:34332     34450             Vias (34450)
#
#      code_insee
# 3         62005
# 560       11106
# 1362      34150
# 1435      38239
# 2309      34332

# %%
df_stations_1.head()
# Out:
#                                            id  \
# 3  stop_point:SNCF:87313759:LongDistanceTrain
# 4  stop_point:SNCF:87342048:LongDistanceTrain
# 5  stop_point:SNCF:87271494:LongDistanceTrain
# 6  stop_point:SNCF:87781278:LongDistanceTrain
# 8  stop_point:SNCF:87586008:LongDistanceTrain
#
#                                name  \
# 3                         Abancourt
# 4                            Achiet
# 5  Aéroport Charles de Gaulle 2 TGV
# 6                              Agde
# 8                              Agen
#
#                                                label           coord.lon  \
# 3                              Abancourt (Abancourt)            1.774297
# 4                           Achiet (Achiet-le-Grand)            2.780112
# 5  Aéroport Charles de Gaulle 2 TGV (Tremblay-en-...            2.570812
# 6                                        Agde (Agde)            3.466203
# 8                                        Agen (Agen)  0.6208669999999999
#
#    coord.lat             stop_area.id                    stop_area.name  \
# 3  49.685621  stop_area:SNCF:87313759                         Abancourt
# 4  50.131919  stop_area:SNCF:87342048                            Achiet
# 5  49.003618  stop_area:SNCF:87271494  Aéroport Charles de Gaulle 2 TGV
# 6   43.31728  stop_area:SNCF:87781278                              Agde
# 8  44.207967  stop_area:SNCF:87586008                              Agen
#
#                                      stop_area.codes stop_area.timezone  \
# 3  [{'type': 'source', 'value': '87313759'}, {'ty...       Europe/Paris
# 4  [{'type': 'source', 'value': '87342048'}, {'ty...       Europe/Paris
# 5  [{'type': 'source', 'value': '87271494'}, {'ty...       Europe/Paris
# 6  [{'type': 'source', 'value': '87781278'}, {'ty...       Europe/Paris
# 8  [{'type': 'source', 'value': '87586008'}, {'ty...       Europe/Paris
#
#                                      stop_area.label stop_area.coord.lon  \
# 3                              Abancourt (Abancourt)            1.774297
# 4                           Achiet (Achiet-le-Grand)            2.780112
# 5  Aéroport Charles de Gaulle 2 TGV (Tremblay-en-...            2.570812
# 6                                        Agde (Agde)            3.466203
# 8                                        Agen (Agen)  0.6208669999999999
#
#   stop_area.coord.lat stop_area.links        admin_id admin_zip  \
# 3           49.685621              []  admin:fr:60001     60220
# 4           50.131919              []  admin:fr:62005     62121
# 5           49.003618              []  admin:fr:93073     93290
# 6            43.31728              []  admin:fr:34003     34300
# 8           44.207967              []  admin:fr:47001     47000
#
#                   admin_label code_insee
# 3           Abancourt (60220)      60001
# 4     Achiet-le-Grand (62121)      62005
# 5  Tremblay-en-France (93290)      93073
# 6                Agde (34300)      34003
# 8                Agen (47000)      47001

# %%
len(df_stations_1)
# Out:
# 709

# %%
len(df_stations_2)
# Out:
# 2268

# %% [markdown]
# # Lignes

# %%
url_lines = "https://api.navitia.io/v1/coverage/sncf/physical_modes/physical_mode:LongDistanceTrain/lines"

# %%
def get_all_lines(url, API_KEY):
    """
    Fonction pour récupérer toutes les lignes
    """
    all_lines = []
    page = 0
    
    while True:
        params = {"count": 1000, "start_page": page}
        response = requests.get(url, params=params, auth=(API_KEY, ""))
                
        data = response.json()

        lines = data.get("lines", [])

        if not lines:
            break

        all_lines.extend(lines)
        page += 1 

    return all_lines

# %%
lignes = get_all_lines(url_lines, API_KEY)
df_lignes = pd.json_normalize(get_all_lines(url_lines, API_KEY))
len(df_lignes)
# Out:
# 245

# %%
df_lignes['commercial_mode.name'].unique()
# Out:
# array(['Aléop', 'BreizhGo', 'DB SNCF', 'Eurostar', 'FLUO', 'Intercités',
#        'Intercités de nuit', 'LEX', 'MOBIGO', 'NOMAD', 'OUIGO',
#        'OUIGO Train Classique', 'REGIONAURA', 'Rémi', 'Rémi Exp', 'SNCF',
#        'TER', 'TER HDF', 'TER NA', 'TGV INOUI', 'TGV Lyria', 'ZOU !',
#        'liO', 'additional service'], dtype=object)

# %%
def get_routes_of_line(line_id):
    '''
    fonction pour récupérer les routes d'une ligne donnée
    '''
    url = f"https://api.navitia.io/v1/coverage/sncf/lines/{line_id}/routes"
    data = requests.get(url, auth=(API_KEY, "")).json()
    return data.get("routes", [])

def get_stop_points_of_route(route_id):
    '''
    fonction pour récupérer les stop points d'une route donnée
    '''
    url = f"https://api.navitia.io/v1/coverage/sncf/routes/{route_id}/stop_points"
    data = requests.get(url, auth=(API_KEY, "")).json()
    return data.get("stop_points", [])

# %%
df_lignes.iloc[3]['id']
# Out:
# 'line:SNCF:FR:Line::71467164-E6B8-40D5-ACC8-ED0FFF3AD2AB:'

# %%
get_routes_of_line(df_lignes.iloc[3]['id'])[0].get('id')
# Out:
# 'route:SNCF:FR:Line::71467164-E6B8-40D5-ACC8-ED0FFF3AD2AB:'

# %%
def get_all_stop_points(all_lines):
    '''
    fonction qui récupère tous les arrêts de toutes les routes
    '''
    all_rows = []

    for line in all_lines:
        line_id = line["id"]
        line_name = line.get("name", "")
        routes = get_routes_of_line(line_id)

        for route in routes:
            route_id = route["id"]
            route_name = route.get("name", "")

            stop_points = get_stop_points_of_route(route_id)

            for sp in stop_points:
                all_rows.append({
                    "line_id": line_id,
                    "line_name": line_name,
                    "route_id": route_id,
                    "route_name": route_name,
                    "stop_point_id": sp["id"],
                    "stop_point_name": sp.get("name", ""),
                    "lon": float(sp["coord"]["lon"]),
                    "lat": float(sp["coord"]["lat"]),
                })

    return pd.DataFrame(all_rows)

# %%
arrets = get_all_stop_points(lignes)

# %%
#retirer les bus et autres non ferroviaires
arrets = arrets.loc[lambda x: (x.stop_point_id.str.contains('Train'))]

# %%
arrets.loc[lambda x: x.line_name == 'Paris Est - Strasbourg']
# Out:
#                   line_id               line_name               route_id  \
# 992  line:SNCF:CSR:333100  Paris Est - Strasbourg  route:SNCF:CSR:333100
# 993  line:SNCF:CSR:333100  Paris Est - Strasbourg  route:SNCF:CSR:333100
# 994  line:SNCF:CSR:333100  Paris Est - Strasbourg  route:SNCF:CSR:333100
#
#                  route_name                               stop_point_id  \
# 992  Paris Est - Strasbourg  stop_point:SNCF:87192039:LongDistanceTrain
# 993  Paris Est - Strasbourg  stop_point:SNCF:87113001:LongDistanceTrain
# 994  Paris Est - Strasbourg  stop_point:SNCF:87212027:LongDistanceTrain
#
#     stop_point_name       lon        lat
# 992            Metz  6.177052  49.109466
# 993       Paris Est  2.359296  48.876793
# 994      Strasbourg  7.734793  48.584532

# %%
#tous les arrêts des lignes Paris - Strasbourg
arrets.loc[lambda x: x.line_name.str.contains('Paris') & x.line_name.str.contains('Strasbourg')]
# Out:
#                                                 line_id  \
# 992                                line:SNCF:CSR:333100
# 993                                line:SNCF:CSR:333100
# 994                                line:SNCF:CSR:333100
# 2239                               line:SNCF:CSR:807100
# 2240                               line:SNCF:CSR:807100
# 2241                               line:SNCF:CSR:807100
# 2242                               line:SNCF:CSR:807100
# 2243                               line:SNCF:CSR:807100
# 2244                               line:SNCF:CSR:807100
# 2245                               line:SNCF:CSR:807100
# 2246                               line:SNCF:CSR:807100
# 2247                               line:SNCF:CSR:807100
# 2248                               line:SNCF:CSR:807100
# 3195  line:stop_area:SNCF:87212027_stop_area:SNCF:87...
#
#                    line_name  \
# 992   Paris Est - Strasbourg
# 993   Paris Est - Strasbourg
# 994   Paris Est - Strasbourg
# 2239  Strasbourg - Paris Est
# 2240  Strasbourg - Paris Est
# 2241  Strasbourg - Paris Est
# 2242  Strasbourg - Paris Est
# 2243  Strasbourg - Paris Est
# 2244  Strasbourg - Paris Est
# 2245  Strasbourg - Paris Est
# 2246  Strasbourg - Paris Est
# 2247  Strasbourg - Paris Est
# 2248  Strasbourg - Paris Est
# 3195  Strasbourg - Paris Est
#
#                                                route_id  \
# 992                               route:SNCF:CSR:333100
# 993                               route:SNCF:CSR:333100
# 994                               route:SNCF:CSR:333100
# 2239                              route:SNCF:CSR:807100
# 2240                              route:SNCF:CSR:807100
# 2241                              route:SNCF:CSR:807100
# 2242                              route:SNCF:CSR:807100
# 2243                              route:SNCF:CSR:807100
# 2244                              route:SNCF:CSR:807100
# 2245                              route:SNCF:CSR:807100
# 2246                              route:SNCF:CSR:807100
# 2247                              route:SNCF:CSR:807100
# 2248                              route:SNCF:CSR:807100
# 3195  route:stop_area:SNCF:87212027_stop_area:SNCF:8...
#
#                   route_name                               stop_point_id  \
# 992   Paris Est - Strasbourg  stop_point:SNCF:87192039:LongDistanceTrain
# 993   Paris Est - Strasbourg  stop_point:SNCF:87113001:LongDistanceTrain
# 994   Paris Est - Strasbourg  stop_point:SNCF:87212027:LongDistanceTrain
# 2239  Strasbourg - Paris Est  stop_point:SNCF:87171926:LongDistanceTrain
# 2240  Strasbourg - Paris Est  stop_point:SNCF:87182014:LongDistanceTrain
# 2241  Strasbourg - Paris Est  stop_point:SNCF:80143503:LongDistanceTrain
# 2242  Strasbourg - Paris Est  stop_point:SNCF:80143198:LongDistanceTrain
# 2243  Strasbourg - Paris Est  stop_point:SNCF:87142109:LongDistanceTrain
# 2244  Strasbourg - Paris Est  stop_point:SNCF:87147322:LongDistanceTrain
# 2245  Strasbourg - Paris Est  stop_point:SNCF:80143099:LongDistanceTrain
# 2246  Strasbourg - Paris Est  stop_point:SNCF:87113001:LongDistanceTrain
# 2247  Strasbourg - Paris Est  stop_point:SNCF:80143255:LongDistanceTrain
# 2248  Strasbourg - Paris Est  stop_point:SNCF:87212027:LongDistanceTrain
# 3195  Strasbourg - Paris Est  stop_point:SNCF:87141150:LongDistanceTrain
#
#               stop_point_name       lon        lat
# 992                      Metz  6.177052  49.109466
# 993                 Paris Est  2.359296  48.876793
# 994                Strasbourg  7.734793  48.584532
# 2239    Champagne-Ardenne TGV  3.994523  49.214769
# 2240                   Colmar  7.347756  48.073527
# 2241  Freiburg (Breisgau) Hbf  7.841600  47.997900
# 2242          Lahr (Schwarzw)  7.835300  48.340600
# 2243             Lorraine TGV  6.169778  48.947713
# 2244                Meuse TGV  5.271024  48.978583
# 2245                Offenburg  7.946800  48.476500
# 2246                Paris Est  2.359296  48.876793
# 2247    Ringsheim Europa-Park  7.773200  48.248900
# 2248               Strasbourg  7.734793  48.584532
# 3195                Lunéville  6.496997  48.587990

# %% [markdown]
# # Trains et horaires

# %% [markdown]
# on cherche à récupérer les trains pour une route donnée (Paris -> Strasbourg par exemple) \
# pour ce faire on requête l'objet vehicle_journeys

# %%
def get_vehicle_journeys(date_start, route_id):
    '''
    fonction pour récupérer les vehicle_journeys d'une route donnée à une date donnée
    '''
    url = f"https://api.navitia.io/v1/coverage/sncf/routes/{route_id}/vehicle_journeys"
    params = {
        "from_datetime": date_start.strftime("%Y%m%dT%H%M%S"),
        "to_datetime": (date_start + pd.Timedelta(days=1)).strftime("%Y%m%dT%H%M%S"),
    }
    data = requests.get(url, params=params, auth=(API_KEY, "")).json()
    return data.get("vehicle_journeys", [])

# %%
trains = pd.json_normalize(get_vehicle_journeys(pd.to_datetime("2025-11-29 00:00:00"), 'route:SNCF:CSR:333100'))

# %%
trains['stop_times'] = trains['stop_times'].apply(lambda x: x[0] if isinstance(x, list) else [])

# %%
trains.tail()
# Out:
#                                                    id  name  \
# 20  vehicle_journey:SNCF:2025-12-03:7691:1187:Long...  7691
# 21  vehicle_journey:SNCF:2025-12-03:7692:1187:Long...  7692
# 22  vehicle_journey:SNCF:2025-12-03:7693:1187:Long...  7693
# 23  vehicle_journey:SNCF:2025-12-03:7694:1187:Long...  7694
# 24  vehicle_journey:SNCF:2025-12-04:7691:1187:Long...  7691
#
#                                            stop_times  \
# 20  [{'arrival_time': '100800', 'utc_arrival_time'...
# 21  [{'arrival_time': '125000', 'utc_arrival_time'...
# 22  [{'arrival_time': '161600', 'utc_arrival_time'...
# 23  [{'arrival_time': '195700', 'utc_arrival_time'...
# 24  [{'arrival_time': '100800', 'utc_arrival_time'...
#
#                                                 codes  \
# 20  [{'type': 'rt_piv', 'value': '2025-12-03:7691:...
# 21  [{'type': 'rt_piv', 'value': '2025-12-03:7692:...
# 22  [{'type': 'rt_piv', 'value': '2025-12-03:7693:...
# 23  [{'type': 'rt_piv', 'value': '2025-12-03:7694:...
# 24  [{'type': 'rt_piv', 'value': '2025-12-04:7691:...
#
#                                             calendars disruptions headsign  \
# 20  [{'week_pattern': {'monday': False, 'tuesday':...          []     7691
# 21  [{'week_pattern': {'monday': False, 'tuesday':...          []     7692
# 22  [{'week_pattern': {'monday': False, 'tuesday':...          []     7693
# 23  [{'week_pattern': {'monday': False, 'tuesday':...          []     7694
# 24  [{'week_pattern': {'monday': False, 'tuesday':...          []     7691
#
#       journey_pattern.id  journey_pattern.name  \
# 20  journey_pattern:2850  journey_pattern:2850
# 21  journey_pattern:2851  journey_pattern:2851
# 22  journey_pattern:2852  journey_pattern:2852
# 23  journey_pattern:2851  journey_pattern:2851
# 24  journey_pattern:2850  journey_pattern:2850
#
#    validity_pattern.beginning_date  \
# 20                        20251127
# 21                        20251127
# 22                        20251127
# 23                        20251127
# 24                        20251127
#
#                                 validity_pattern.days  \
# 20  0000000000000000000000000000000000000000000000...
# 21  0000000000000000000000000000000000000000000000...
# 22  0000000000000000000000000000000000000000000000...
# 23  0000000000000000000000000000000000000000000000...
# 24  0000000000000000000000000000000000000000000000...
#
#                                         trip.id trip.name
# 20  SNCF:2025-12-03:7691:1187:LongDistanceTrain      7691
# 21  SNCF:2025-12-03:7692:1187:LongDistanceTrain      7692
# 22  SNCF:2025-12-03:7693:1187:LongDistanceTrain      7693
# 23  SNCF:2025-12-03:7694:1187:LongDistanceTrain      7694
# 24  SNCF:2025-12-04:7691:1187:LongDistanceTrain      7691

# %%
def decompose_time(hhmmss: str) -> tuple[int, int, int]:
    hh = int(hhmmss[0:2])
    mm = int(hhmmss[2:4])
    ss = int(hhmmss[4:6])
    return hh, mm, ss

def get_stop_times(trajet):
    date = trajet['id'].split(':')[2]
    date = datetime.strptime(date, "%Y-%m-%d")

    last_time_in_seconds = None
    stops = []

    for st in trajet["stop_times"]:
        raw_arr = st.get("arrival_time")
        raw_dep = st.get("departure_time")

        # convertir HHMMSS en (h, m, s)
        h_arr, m_arr, s_arr = decompose_time(raw_arr) if raw_arr else (0, 0, 0)
        h_dep, m_dep, s_dep = decompose_time(raw_dep) if raw_dep else (0, 0, 0)

        # calculer secondes depuis 00:00:00
        arr_seconds = h_arr * 3600 + m_arr * 60 + s_arr

        # si on détecte que l'heure "recule", c’est qu’on a traversé minuit
        if last_time_in_seconds is not None and arr_seconds < last_time_in_seconds:
            date += timedelta(days=1)

        # construire les datetime complets
        arrival_dt = datetime.combine(date, datetime.min.time()).replace(
            hour=h_arr, minute=m_arr, second=s_arr
        )
        departure_dt = datetime.combine(date, datetime.min.time()).replace(
            hour=h_dep, minute=m_dep, second=s_dep
        )

        stops.append({
            "stop_point_id": st["stop_point"]["id"],
            "stop_name": st["stop_point"]["name"],
            "arrival_dt": arrival_dt,
            "departure_dt": departure_dt,
        })

        # mettre à jour la dernière heure du dernier arrêt parcouru 
        last_time_in_seconds = arr_seconds
        
    return stops

# %%
get_stop_times(trains.iloc[6])
# Out:
# [{'stop_point_id': 'stop_point:SNCF:87113001:LongDistanceTrain',
#   'stop_name': 'Paris Est',
#   'arrival_dt': datetime.datetime(2025, 11, 29, 16, 16),
#   'departure_dt': datetime.datetime(2025, 11, 29, 16, 16)},
#  {'stop_point_id': 'stop_point:SNCF:87192039:LongDistanceTrain',
#   'stop_name': 'Metz',
#   'arrival_dt': datetime.datetime(2025, 11, 29, 17, 41),
#   'departure_dt': datetime.datetime(2025, 11, 29, 18, 4)},
#  {'stop_point_id': 'stop_point:SNCF:87212027:LongDistanceTrain',
#   'stop_name': 'Strasbourg',
#   'arrival_dt': datetime.datetime(2025, 11, 29, 19, 0),
#   'departure_dt': datetime.datetime(2025, 11, 29, 19, 0)}]

# %% [markdown]
# # Graphe des trajets

# %% [markdown]
# on requête directement tous les trains pour une période donnée (sur une fenêtre de 24h par exemple)
# Pour tous les trains, on ajoute une arrête entre deux arrêts (gares) consécutifs et on met un poids = la durée du parcourt

# %%
#récupérer tous les journeys pour une date donnée
def get_all_journeys(since):
    """"
        Fonction pour récupérer tous les vehicle_journeys à partir de la date 'since' jusqu'à 'since + 24h'
        Args:
            since (datetime): date de début pour la récupération des vehicle_journeys
    """
    until = since + timedelta(hours=24)
    since_str = since.strftime("%Y%m%dT%H%M%S")
    until_str = until.strftime("%Y%m%dT%H%M%S")

    page = 0
    headers = {"Authorization": API_KEY}
    all_vj = []
    
    while True:
        
        url = f"https://api.navitia.io/v1/coverage/sncf/physical_modes/physical_mode:LongDistanceTrain/vehicle_journeys?since={since_str}&until={until_str}&count=500&start_page={page}"
        r = requests.get(url, headers=headers)
        
        if r.status_code != 200:
            break

        data = r.json()

        if "vehicle_journeys" in data:
            all_vj.extend(data["vehicle_journeys"])

        if not data.get("vehicle_journeys"):
            break

        page += 1
        
    return all_vj

# %%
since_date = datetime(2025, 12, 1, 0, 0, 0)
vehicle_journeys = get_all_journeys(since_date)

# %%
df_vehicle_journeys = pd.json_normalize(vehicle_journeys)

# %%
df_vehicle_journeys['stop_times'][0]
# Out:
# [{'arrival_time': '153700',
#   'utc_arrival_time': '143700',
#   'departure_time': '153700',
#   'utc_departure_time': '143700',
#   'headsign': '858721',
#   'stop_point': {'id': 'stop_point:SNCF:87487603:LongDistanceTrain',
#    'name': 'Saumur',
#    'label': 'Saumur (Saumur)',
#    'coord': {'lon': '-0.07140299999999999', 'lat': '47.268994'},
#    'links': [],
#    'equipments': []},
#   'pickup_allowed': True,
#   'drop_off_allowed': False,
#   'skipped_stop': False},
#  {'arrival_time': '154900',
#   'utc_arrival_time': '144900',
#   'departure_time': '155000',
#   'utc_departure_time': '145000',
#   'headsign': '858721',
#   'stop_point': {'id': 'stop_point:SNCF:87487884:LongDistanceTrain',
#    'name': 'La Ménitré',
#    'label': 'La Ménitré (La Ménitré)',
#    'coord': {'lon': '-0.275838', 'lat': '47.397383'},
#    'links': [],
#    'equipments': []},
#   'pickup_allowed': True,
#   'drop_off_allowed': True,
#   'skipped_stop': False},
#  {'arrival_time': '160100',
#   'utc_arrival_time': '150100',
#   'departure_time': '160300',
#   'utc_departure_time': '150300',
#   'headsign': '858721',
#   'stop_point': {'id': 'stop_point:SNCF:87484006:LongDistanceTrain',
#    'name': 'Angers Saint-Laud',
#    'label': 'Angers Saint-Laud (Angers)',
#    'coord': {'lon': '-0.55677', 'lat': '47.464649'},
#    'links': [],
#    'equipments': []},
#   'pickup_allowed': True,
#   'drop_off_allowed': True,
#   'skipped_stop': False},
#  {'arrival_time': '162800',
#   'utc_arrival_time': '152800',
#   'departure_time': '162900',
#   'utc_departure_time': '152900',
#   'headsign': '858721',
#   'stop_point': {'id': 'stop_point:SNCF:87481192:LongDistanceTrain',
#    'name': 'Ancenis',
#    'label': 'Ancenis (Ancenis-Saint-Géréon)',
#    'coord': {'lon': '-1.177763', 'lat': '47.369334'},
#    'links': [],
#    'equipments': []},
#   'pickup_allowed': True,
#   'drop_off_allowed': True,
#   'skipped_stop': False},
#  {'arrival_time': '164700',
#   'utc_arrival_time': '154700',
#   'departure_time': '164700',
#   'utc_departure_time': '154700',
#   'headsign': '858721',
#   'stop_point': {'id': 'stop_point:SNCF:87481002:LongDistanceTrain',
#    'name': 'Nantes',
#    'label': 'Nantes (Nantes)',
#    'coord': {'lon': '-1.542077', 'lat': '47.217491'},
#    'links': [],
#    'equipments': []},
#   'pickup_allowed': False,
#   'drop_off_allowed': True,
#   'skipped_stop': False}]

# %%
def parse_hhmmss(hhmmss: str) -> time:
    """Convertit l'heure au format hhmmss en un objet time"""
    hh = int(hhmmss[0:2])
    mm = int(hhmmss[2:4])
    ss = int(hhmmss[4:6])
    return time(hour=hh, minute=mm, second=ss)

def hhmmss_to_seconds(hhmmss: str) -> int:
    """Convertit l'heure hhmmss en secondes (écoulées depuis minuit)"""
    hh = int(hhmmss[0:2])
    mm = int(hhmmss[2:4])
    ss = int(hhmmss[4:6])
    return hh * 3600 + mm * 60 + ss

# %%
def build_graph_from_vehicle_journeys(df_vehicle_journeys):
    """Créer un graphe orienté à partir des vehicle_journeys"""
    G = nx.DiGraph()

    # Parcourir chaque vehicle_journey
    for _, row in df_vehicle_journeys.iterrows():
        stop_times = row['stop_times']  # Liste des arrêts pour ce train

        # Parcourir les gares consécutives pour créer des arêtes
        for i in range(len(stop_times) - 1):
            current_stop = stop_times[i]
            next_stop = stop_times[i + 1]

            from_stop_id = current_stop['stop_point']['id']
            from_stop_name = current_stop['stop_point']['name']
            to_stop_id = next_stop['stop_point']['id']
            to_stop_name = next_stop['stop_point']['name']

            # Calculer la durée de trajet en secondes
            departure_time = current_stop['departure_time']
            arrival_time = next_stop['arrival_time']
            departure_seconds = hhmmss_to_seconds(departure_time)
            arrival_seconds = hhmmss_to_seconds(arrival_time)
            duration = arrival_seconds - departure_seconds

            # Ajouter les nœuds (gares) au graphe
            G.add_node(from_stop_id, name=from_stop_name)
            G.add_node(to_stop_id, name=to_stop_name)

            # Ajouter une arête entre les deux gares
            G.add_edge(
                from_stop_id,
                to_stop_id,
                weight=duration,  # pondération par rapport au temps de trajet
                train=row['id'],
                departure_time=departure_time,
                arrival_time=arrival_time 
            )

    return G

# %%
G = build_graph_from_vehicle_journeys(df_vehicle_journeys)

print(f"Nombre de nœuds : {G.number_of_nodes()}")
print(f"Nombre d'arêtes : {G.number_of_edges()}")
# Out:
# Nombre de nœuds : 701
# Nombre d'arêtes : 1964

# %%
G.nodes
# Out:
# NodeView(('stop_point:SNCF:87487603:LongDistanceTrain', 'stop_point:SNCF:87487884:LongDistanceTrain', 'stop_point:SNCF:87484006:LongDistanceTrain', 'stop_point:SNCF:87481192:LongDistanceTrain', 'stop_point:SNCF:87481002:LongDistanceTrain', 'stop_point:SNCF:87571000:LongDistanceTrain', 'stop_point:SNCF:87571240:LongDistanceTrain', 'stop_point:SNCF:87574343:LongDistanceTrain', 'stop_point:SNCF:87574319:LongDistanceTrain', 'stop_point:SNCF:87574004:LongDistanceTrain', 'stop_point:SNCF:87574194:LongDistanceTrain', 'stop_point:SNCF:87574160:LongDistanceTrain', 'stop_point:SNCF:87574137:LongDistanceTrain', 'stop_point:SNCF:87543009:LongDistanceTrain', 'stop_point:SNCF:87396002:LongDistanceTrain', 'stop_point:SNCF:87396309:LongDistanceTrain', 'stop_point:SNCF:87396325:LongDistanceTrain', 'stop_point:SNCF:87394296:LongDistanceTrain', 'stop_point:SNCF:87394254:LongDistanceTrain', 'stop_point:SNCF:87394221:LongDistanceTrain', 'stop_point:SNCF:87394007:LongDistanceTrain', 'stop_point:SNCF:87394130:LongDistanceTrain', 'stop_point:SNCF:87394114:LongDistanceTrain', 'stop_point:SNCF:87393314:LongDistanceTrain', 'stop_point:SNCF:87393009:LongDistanceTrain', 'stop_point:SNCF:87391003:LongDistanceTrain', 'stop_point:SNCF:87396408:LongDistanceTrain', 'stop_point:SNCF:87478404:LongDistanceTrain', 'stop_point:SNCF:87471508:LongDistanceTrain', 'stop_point:SNCF:87471003:LongDistanceTrain', 'stop_point:SNCF:87471300:LongDistanceTrain', 'stop_point:SNCF:87476606:LongDistanceTrain', 'stop_point:SNCF:87476200:LongDistanceTrain', 'stop_point:SNCF:87476002:LongDistanceTrain', 'stop_point:SNCF:87474098:LongDistanceTrain', 'stop_point:SNCF:87481838:LongDistanceTrain', 'stop_point:SNCF:87481846:LongDistanceTrain', 'stop_point:SNCF:87476671:LongDistanceTrain', 'stop_point:SNCF:87476259:LongDistanceTrain', 'stop_point:SNCF:87476317:LongDistanceTrain', 'stop_point:SNCF:87474155:LongDistanceTrain', 'stop_point:SNCF:87396564:LongDistanceTrain', 'stop_point:SNCF:87396606:LongDistanceTrain', 'stop_point:SNCF:87571554:LongDistanceTrain', 'stop_point:SNCF:87396044:LongDistanceTrain', 'stop_point:SNCF:87396077:LongDistanceTrain', 'stop_point:SNCF:87444711:LongDistanceTrain', 'stop_point:SNCF:87444695:LongDistanceTrain', 'stop_point:SNCF:87444562:LongDistanceTrain', 'stop_point:SNCF:87444539:LongDistanceTrain', 'stop_point:SNCF:87444216:LongDistanceTrain', 'stop_point:SNCF:87444208:LongDistanceTrain', 'stop_point:SNCF:87444000:LongDistanceTrain', 'stop_point:SNCF:87396036:LongDistanceTrain', 'stop_point:SNCF:87396093:LongDistanceTrain', 'stop_point:SNCF:87396051:LongDistanceTrain', 'stop_point:SNCF:87396028:LongDistanceTrain', 'stop_point:SNCF:87743872:LongDistanceTrain', 'stop_point:SNCF:87396549:LongDistanceTrain', 'stop_point:SNCF:87396556:LongDistanceTrain', 'stop_point:SNCF:87396580:LongDistanceTrain', 'stop_point:SNCF:87396572:LongDistanceTrain', 'stop_point:SNCF:87396598:LongDistanceTrain', 'stop_point:SNCF:87487876:LongDistanceTrain', 'stop_point:SNCF:87487892:LongDistanceTrain', 'stop_point:SNCF:87487843:LongDistanceTrain', 'stop_point:SNCF:87701532:LongDistanceTrain', 'stop_point:SNCF:87571794:LongDistanceTrain', 'stop_point:SNCF:87571828:LongDistanceTrain', 'stop_point:SNCF:87571836:LongDistanceTrain', 'stop_point:SNCF:87571802:LongDistanceTrain', 'stop_point:SNCF:87571810:LongDistanceTrain', 'stop_point:SNCF:87571844:LongDistanceTrain', 'stop_point:SNCF:87571851:LongDistanceTrain', 'stop_point:SNCF:87396275:LongDistanceTrain', 'stop_point:SNCF:87396283:LongDistanceTrain', 'stop_point:SNCF:87396291:LongDistanceTrain', 'stop_point:SNCF:87396317:LongDistanceTrain', 'stop_point:SNCF:87396333:LongDistanceTrain', 'stop_point:SNCF:87394288:LongDistanceTrain', 'stop_point:SNCF:87394270:LongDistanceTrain', 'stop_point:SNCF:87394247:LongDistanceTrain', 'stop_point:SNCF:87394213:LongDistanceTrain', 'stop_point:SNCF:87394205:LongDistanceTrain', 'stop_point:SNCF:87478743:LongDistanceTrain', 'stop_point:SNCF:87478750:LongDistanceTrain', 'stop_point:SNCF:87478768:LongDist ...
